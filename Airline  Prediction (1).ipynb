# %% [markdown]
# # Contents
# *  Datasets 1
# *  isna() function 2
# *  dropping columns 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('Data_Train.xlsx')

# %% [markdown]
# # 1. Datasets head value(5)

# %%
data.head(10)
# Out:
#              Airline Date_of_Journey    Source Destination  \
# 0             IndiGo      24/03/2019  Banglore   New Delhi
# 1          Air India       1/05/2019   Kolkata    Banglore
# 2        Jet Airways       9/06/2019     Delhi      Cochin
# 3             IndiGo      12/05/2019   Kolkata    Banglore
# 4             IndiGo      01/03/2019  Banglore   New Delhi
# 5           SpiceJet      24/06/2019   Kolkata    Banglore
# 6        Jet Airways      12/03/2019  Banglore   New Delhi
# 7        Jet Airways      01/03/2019  Banglore   New Delhi
# 8        Jet Airways      12/03/2019  Banglore   New Delhi
# 9  Multiple carriers      27/05/2019     Delhi      Cochin
#
#                    Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0              BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1  CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2  DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# ...

# %%
data.shape
# Out:
# (10683, 11)

# %% [markdown]
# #  2.isna() - meaning ena nah null values la show panra function dhn ithu

# %%
data.isna()
# Out:
#        Airline  Date_of_Journey  Source  Destination  Route  Dep_Time  \
# 0        False            False   False        False  False     False
# 1        False            False   False        False  False     False
# 2        False            False   False        False  False     False
# 3        False            False   False        False  False     False
# 4        False            False   False        False  False     False
# ...        ...              ...     ...          ...    ...       ...
# 10678    False            False   False        False  False     False
# 10679    False            False   False        False  False     False
# 10680    False            False   False        False  False     False
# 10681    False            False   False        False  False     False
# 10682    False            False   False        False  False     False
#
#        Arrival_Time  Duration  Total_Stops  Additional_Info  Additional_Info.1
# ...

# %% [markdown]
# # 3. isna().sum - ithuku ena meaning nah total irukura datas la engalam null values iruku nu kamchi kuduthudum athunala dhn inths null value function ipdi type pani podurom.

# %%
data.isna().sum()
# Out:
# Airline              0
# Date_of_Journey      0
# Source               0
# Destination          0
# Route                1
# Dep_Time             0
# Arrival_Time         0
# Duration             0
# Total_Stops          1
# Additional_Info      0
# Additional_Info.1    0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (10682, 11)

# %%
data.isna().sum()
# Out:
# Airline              0
# Date_of_Journey      0
# Source               0
# Destination          0
# Route                0
# Dep_Time             0
# Arrival_Time         0
# Duration             0
# Total_Stops          0
# Additional_Info      0
# Additional_Info.1    0
# dtype: int64

# %%
data.head(5)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info
# 1    05:50         13:15   7h 25m     2 stops         No info
# 2    09:25  04:25 10 Jun      19h     2 stops         No info
# 3    18:05         23:30   5h 25m      1 stop         No info
# 4    16:50         21:35   4h 45m      1 stop         No info
#
#   Additional_Info.1
# 0           No info
# 1           No info
# 2           No info
# 3           No info
# 4           No info

# %%
data.dtypes
# Out:
# Airline              object
# Date_of_Journey      object
# Source               object
# Destination          object
# Route                object
# Dep_Time             object
# Arrival_Time         object
# Duration             object
# Total_Stops          object
# Additional_Info      object
# Additional_Info.1    object
# dtype: object

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Additional_Info.1'],
#       dtype='object')

# %% [markdown]
# # 3.1 changing the date column

# %%
def change_to_date(column):
    data[column]=pd.to_datetime(data[column])

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Additional_Info.1'],
#       dtype='object')

# %%
for i in ['Date_of_Journey', 'Dep_Time', 'Arrival_Time']:
    change_to_date(i)
# Out:
# C:\Users\hari6\AppData\Local\Temp\ipykernel_21016\271803378.py:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data[column]=pd.to_datetime(data[column])
# C:\Users\hari6\AppData\Local\Temp\ipykernel_21016\271803378.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data[column]=pd.to_datetime(data[column])
# C:\Users\hari6\AppData\Local\Temp\ipykernel_21016\271803378.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data[column]=pd.to_datetime(data[column])

# %%
data.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2024-10-10 22:20:00 2024-03-22 01:10:00   2h 50m    non-stop
# 1 2024-10-10 05:50:00 2024-10-10 13:15:00   7h 25m     2 stops
# 2 2024-10-10 09:25:00 2024-06-10 04:25:00      19h     2 stops
#
#   Additional_Info Additional_Info.1
# 0         No info           No info
# 1         No info           No info
# 2         No info           No info

# %%
data.dtypes
# Out:
# Airline                      object
# Date_of_Journey      datetime64[ns]
# Source                       object
# Destination                  object
# Route                        object
# Dep_Time             datetime64[ns]
# Arrival_Time         datetime64[ns]
# Duration                     object
# Total_Stops                  object
# Additional_Info              object
# Additional_Info.1            object
# dtype: object

# %%
data['Journet_date']=data['Date_of_Journey'].dt.day
data['Journet_month']=data['Date_of_Journey'].dt.month

# %%
data.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2024-10-10 22:20:00 2024-03-22 01:10:00   2h 50m    non-stop
# 1 2024-10-10 05:50:00 2024-10-10 13:15:00   7h 25m     2 stops
# 2 2024-10-10 09:25:00 2024-06-10 04:25:00      19h     2 stops
#
#   Additional_Info Additional_Info.1  Journet_date  Journet_month
# 0         No info           No info            24              3
# 1         No info           No info             1              5
# 2         No info           No info             9              6

# %%
data.dtypes
# Out:
# Airline                      object
# Date_of_Journey      datetime64[ns]
# Source                       object
# Destination                  object
# Route                        object
# Dep_Time             datetime64[ns]
# Arrival_Time         datetime64[ns]
# Duration                     object
# Total_Stops                  object
# Additional_Info              object
# Additional_Info.1            object
# Journet_date                  int32
# Journet_month                 int32
# dtype: object

# %% [markdown]
# # 4. dropping columns

# %%
data.drop(['Additional_Info.1'],axis=1,inplace=True)

# %%
data.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2024-10-10 22:20:00 2024-03-22 01:10:00   2h 50m    non-stop
# 1 2024-10-10 05:50:00 2024-10-10 13:15:00   7h 25m     2 stops
# 2 2024-10-10 09:25:00 2024-06-10 04:25:00      19h     2 stops
#
#   Additional_Info  Journet_date  Journet_month
# 0         No info            24              3
# 1         No info             1              5
# 2         No info             9              6

# %%
data['Arrival_hour']=data['Arrival_Time'].dt.hour
data['Arrival_minute']=data['Arrival_Time'].dt.minute

# %%
def getting_hr(df,column):
    df[column+'hour']=df[column].dt.hour
def getting_min(df,column):
    df[column+'minute']=df[column].dt.minute
def drop_column(df,column):
    df.drop(column,axis=1,inplace=True)

# %%
getting_hr(data,'Arrival_Time')
getting_min(data,'Arrival_Time')
getting_hr(data,'Dep_Time')
getting_min(data,'Dep_Time')

# %%
data.head(5)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2024-10-10 22:20:00 2024-03-22 01:10:00   2h 50m    non-stop
# 1 2024-10-10 05:50:00 2024-10-10 13:15:00   7h 25m     2 stops
# 2 2024-10-10 09:25:00 2024-06-10 04:25:00      19h     2 stops
# 3 2024-10-10 18:05:00 2024-10-10 23:30:00   5h 25m      1 stop
# 4 2024-10-10 16:50:00 2024-10-10 21:35:00   4h 45m      1 stop
#
#   Additional_Info  Journet_date  Journet_month  Arrival_hour  Arrival_minute  \
# ...

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Journet_date', 'Journet_month', 'Arrival_hour',
#        'Arrival_minute', 'Arrival_Timehour', 'Arrival_Timeminute',
#        'Dep_Timehour', 'Dep_Timeminute'],
#       dtype='object')

# %% [markdown]
# # 5. changing the column name (ie:journet_month into journey_month)

# %%
data['Dep_date']=data['Dep_Time'].dt.day
data['Dep_month']=data['Dep_Time'].dt.month
data['Dep_year']=data['Dep_Time'].dt.year

# %%
data.rename(columns = {'Journet_month':'Journey_month','Journet_date':'Journey_date'})
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi
# 1        Air India      2019-05-01   Kolkata    Banglore
# 2      Jet Airways      2019-06-09     Delhi      Cochin
# 3           IndiGo      2019-05-12   Kolkata    Banglore
# 4           IndiGo      2019-03-01  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia      2019-04-09   Kolkata    Banglore
# 10679    Air India      2019-04-27   Kolkata    Banglore
# 10680  Jet Airways      2019-04-27  Banglore       Delhi
# 10681      Vistara      2019-03-01  Banglore   New Delhi
# 10682    Air India      2019-05-09     Delhi      Cochin
#
#                        Route            Dep_Time        Arrival_Time Duration  \
# 0                  BLR → DEL 2024-10-10 22:20:00 2024-03-22 01:10:00   2h 50m
# 1      CCU → IXR → BBI → BLR 2024-10-10 05:50:00 2024-10-10 13:15:00   7h 25m
# ...

# %%
data.dtypes
# Out:
# Airline                       object
# Date_of_Journey       datetime64[ns]
# Source                        object
# Destination                   object
# Route                         object
# Dep_Time              datetime64[ns]
# Arrival_Time          datetime64[ns]
# Duration                      object
# Total_Stops                   object
# Additional_Info               object
# Journet_date                   int32
# Journet_month                  int32
# Arrival_hour                   int32
# Arrival_minute                 int32
# Arrival_Timehour               int32
# Arrival_Timeminute             int32
# Dep_Timehour                   int32
# Dep_Timeminute                 int32
# Dep_date                       int32
# Dep_month                      int32
# Dep_year                       int32
# dtype: object

# %%
duration=list(data['Duration'])

# %%
duration
# Out:
# ['2h 50m',
#  '7h 25m',
#  '19h',
#  '5h 25m',
#  '4h 45m',
#  '2h 25m',
#  '15h 30m',
#  '21h 5m',
#  '25h 30m',
#  '7h 50m',
#  '13h 15m',
#  '2h 35m',
#  '2h 15m',
#  '12h 10m',
#  '2h 35m',
#  '26h 35m',
#  '4h 30m',
#  '22h 35m',
#  '23h',
#  '20h 35m',
#  '5h 10m',
#  '15h 20m',
#  '2h 50m',
#  '2h 55m',
#  '13h 20m',
#  '15h 10m',
#  '5h 45m',
#  '5h 55m',
#  '2h 50m',
#  '2h 15m',
#  '2h 15m',
#  '13h 25m',
#  '2h 50m',
#  '22h',
#  '5h 30m',
#  '10h 25m',
#  '5h 15m',
#  '2h 30m',
#  '6h 15m',
#  '11h 55m',
#  '11h 5m',
#  '8h 30m',
#  '22h 5m',
#  '2h 45m',
#  '12h',
#  '2h 50m',
#  '2h 50m',
#  '2h 15m',
#  '16h 5m',
#  '19h 55m',
#  '3h 15m',
#  '25h 20m',
#  '2h 50m',
#  '3h',
#  '2h 50m',
#  '16h 15m',
#  '15h 5m',
#  '2h 15m',
#  '6h 30m',
#  '25h 5m',
#  '12h 25m',
#  '27h 20m',
#  '10h 15m',
#  '10h 30m',
#  '2h 15m',
#  '10h 25m',
#  '2h 50m',
#  '1h 30m',
#  '13h 20m',
#  '2h 15m',
#  '1h 25m',
#  '26h 30m',
#  '7h 20m',
#  '13h 30m',
#  '5h',
#  '2h 45m',
# ...

# %%
data.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2024-10-10 22:20:00 2024-03-22 01:10:00   2h 50m    non-stop
# 1 2024-10-10 05:50:00 2024-10-10 13:15:00   7h 25m     2 stops
# 2 2024-10-10 09:25:00 2024-06-10 04:25:00      19h     2 stops
#
#   Additional_Info  ...  Journet_month  Arrival_hour  Arrival_minute  \
# 0         No info  ...              3             1              10
# 1         No info  ...              5            13              15
# 2         No info  ...              6             4              25
#
#    Arrival_Timehour  Arrival_Timeminute  Dep_Timehour  Dep_Timeminute  \
# ...

# %%
data.shape
# Out:
# (10682, 21)

# %%
data.Arrival_Time
# Out:
# 0       2024-03-22 01:10:00
# 1       2024-10-10 13:15:00
# 2       2024-06-10 04:25:00
# 3       2024-10-10 23:30:00
# 4       2024-10-10 21:35:00
#                 ...
# 10678   2024-10-10 22:25:00
# 10679   2024-10-10 23:20:00
# 10680   2024-10-10 11:20:00
# 10681   2024-10-10 14:10:00
# 10682   2024-10-10 19:15:00
# Name: Arrival_Time, Length: 10682, dtype: datetime64[ns]

# %%
data['Arrival_Time']
# Out:
# 0       2024-03-22 01:10:00
# 1       2024-10-10 13:15:00
# 2       2024-06-10 04:25:00
# 3       2024-10-10 23:30:00
# 4       2024-10-10 21:35:00
#                 ...
# 10678   2024-10-10 22:25:00
# 10679   2024-10-10 23:20:00
# 10680   2024-10-10 11:20:00
# 10681   2024-10-10 14:10:00
# 10682   2024-10-10 19:15:00
# Name: Arrival_Time, Length: 10682, dtype: datetime64[ns]

# %%
data['Arrival_Time'],['Date_of_Journey']
# Out:
# (0       2024-03-22 01:10:00
#  1       2024-10-10 13:15:00
#  2       2024-06-10 04:25:00
#  3       2024-10-10 23:30:00
#  4       2024-10-10 21:35:00
#                  ...
#  10678   2024-10-10 22:25:00
#  10679   2024-10-10 23:20:00
#  10680   2024-10-10 11:20:00
#  10681   2024-10-10 14:10:00
#  10682   2024-10-10 19:15:00
#  Name: Arrival_Time, Length: 10682, dtype: datetime64[ns],
#  ['Date_of_Journey'])

# %%
data['Airline'],['Source']
# Out:
# (0             IndiGo
#  1          Air India
#  2        Jet Airways
#  3             IndiGo
#  4             IndiGo
#              ...
#  10678       Air Asia
#  10679      Air India
#  10680    Jet Airways
#  10681        Vistara
#  10682      Air India
#  Name: Airline, Length: 10682, dtype: object,
#  ['Source'])

# %%
data[['Airline','Source']].head(3)
# Out:
#        Airline    Source
# 0       IndiGo  Banglore
# 1    Air India   Kolkata
# 2  Jet Airways     Delhi

# %%
data[['Arrival_Time','Date_of_Journey']].head(10)
# Out:
#          Arrival_Time Date_of_Journey
# 0 2024-03-22 01:10:00      2019-03-24
# 1 2024-10-10 13:15:00      2019-05-01
# 2 2024-06-10 04:25:00      2019-06-09
# 3 2024-10-10 23:30:00      2019-05-12
# 4 2024-10-10 21:35:00      2019-03-01
# 5 2024-10-10 11:25:00      2019-06-24
# 6 2024-03-13 10:25:00      2019-03-12
# 7 2024-03-02 05:05:00      2019-03-01
# 8 2024-03-13 10:25:00      2019-03-12
# 9 2024-10-10 19:15:00      2019-05-27

# %%
data[['Arrival_Time','Date_of_Journey']].tail(10)
# Out:
#              Arrival_Time Date_of_Journey
# 10673 2024-05-28 04:25:00      2019-05-27
# 10674 2024-03-13 21:20:00      2019-03-12
# 10675 2024-10-10 07:40:00      2019-06-09
# 10676 2024-10-10 19:00:00      2019-05-01
# 10677 2024-10-10 08:35:00      2019-05-21
# 10678 2024-10-10 22:25:00      2019-04-09
# 10679 2024-10-10 23:20:00      2019-04-27
# 10680 2024-10-10 11:20:00      2019-04-27
# 10681 2024-10-10 14:10:00      2019-03-01
# 10682 2024-10-10 19:15:00      2019-05-09

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Journet_date', 'Journet_month', 'Arrival_hour',
#        'Arrival_minute', 'Arrival_Timehour', 'Arrival_Timeminute',
#        'Dep_Timehour', 'Dep_Timeminute', 'Dep_date', 'Dep_month', 'Dep_year'],
#       dtype='object')

# %%
data[['Airline', 'Date_of_Journey', 'Source', 'Destination']].head(10)
# Out:
#              Airline Date_of_Journey    Source Destination
# 0             IndiGo      2019-03-24  Banglore   New Delhi
# 1          Air India      2019-05-01   Kolkata    Banglore
# 2        Jet Airways      2019-06-09     Delhi      Cochin
# 3             IndiGo      2019-05-12   Kolkata    Banglore
# 4             IndiGo      2019-03-01  Banglore   New Delhi
# 5           SpiceJet      2019-06-24   Kolkata    Banglore
# 6        Jet Airways      2019-03-12  Banglore   New Delhi
# 7        Jet Airways      2019-03-01  Banglore   New Delhi
# 8        Jet Airways      2019-03-12  Banglore   New Delhi
# 9  Multiple carriers      2019-05-27     Delhi      Cochin

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi
# 1        Air India      2019-05-01   Kolkata    Banglore
# 2      Jet Airways      2019-06-09     Delhi      Cochin
# 3           IndiGo      2019-05-12   Kolkata    Banglore
# 4           IndiGo      2019-03-01  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia      2019-04-09   Kolkata    Banglore
# 10679    Air India      2019-04-27   Kolkata    Banglore
# 10680  Jet Airways      2019-04-27  Banglore       Delhi
# 10681      Vistara      2019-03-01  Banglore   New Delhi
# 10682    Air India      2019-05-09     Delhi      Cochin
#
#                        Route            Dep_Time        Arrival_Time Duration  \
# 0                  BLR → DEL 2024-10-10 22:20:00 2024-03-22 01:10:00   2h 50m
# 1      CCU → IXR → BBI → BLR 2024-10-10 05:50:00 2024-10-10 13:15:00   7h 25m
# ...

# %%
duration=list(data['Duration'])

# %%
duration
# Out:
# ['2h 50m',
#  '7h 25m',
#  '19h',
#  '5h 25m',
#  '4h 45m',
#  '2h 25m',
#  '15h 30m',
#  '21h 5m',
#  '25h 30m',
#  '7h 50m',
#  '13h 15m',
#  '2h 35m',
#  '2h 15m',
#  '12h 10m',
#  '2h 35m',
#  '26h 35m',
#  '4h 30m',
#  '22h 35m',
#  '23h',
#  '20h 35m',
#  '5h 10m',
#  '15h 20m',
#  '2h 50m',
#  '2h 55m',
#  '13h 20m',
#  '15h 10m',
#  '5h 45m',
#  '5h 55m',
#  '2h 50m',
#  '2h 15m',
#  '2h 15m',
#  '13h 25m',
#  '2h 50m',
#  '22h',
#  '5h 30m',
#  '10h 25m',
#  '5h 15m',
#  '2h 30m',
#  '6h 15m',
#  '11h 55m',
#  '11h 5m',
#  '8h 30m',
#  '22h 5m',
#  '2h 45m',
#  '12h',
#  '2h 50m',
#  '2h 50m',
#  '2h 15m',
#  '16h 5m',
#  '19h 55m',
#  '3h 15m',
#  '25h 20m',
#  '2h 50m',
#  '3h',
#  '2h 50m',
#  '16h 15m',
#  '15h 5m',
#  '2h 15m',
#  '6h 30m',
#  '25h 5m',
#  '12h 25m',
#  '27h 20m',
#  '10h 15m',
#  '10h 30m',
#  '2h 15m',
#  '10h 25m',
#  '2h 50m',
#  '1h 30m',
#  '13h 20m',
#  '2h 15m',
#  '1h 25m',
#  '26h 30m',
#  '7h 20m',
#  '13h 30m',
#  '5h',
#  '2h 45m',
# ...

# %%
for i in range(len(duration)):
    if len(duration[i].split(' '))==2:
        pass
    else:
        if 'h' in duration[i]:
            duration[i]=duration[i]+ ' 0m'
        else:
            duration[i]='0h '+duration[i]

# %%
duration
# Out:
# ['2h 50m',
#  '7h 25m',
#  '19h 0m',
#  '5h 25m',
#  '4h 45m',
#  '2h 25m',
#  '15h 30m',
#  '21h 5m',
#  '25h 30m',
#  '7h 50m',
#  '13h 15m',
#  '2h 35m',
#  '2h 15m',
#  '12h 10m',
#  '2h 35m',
#  '26h 35m',
#  '4h 30m',
#  '22h 35m',
#  '23h 0m',
#  '20h 35m',
#  '5h 10m',
#  '15h 20m',
#  '2h 50m',
#  '2h 55m',
#  '13h 20m',
#  '15h 10m',
#  '5h 45m',
#  '5h 55m',
#  '2h 50m',
#  '2h 15m',
#  '2h 15m',
#  '13h 25m',
#  '2h 50m',
#  '22h 0m',
#  '5h 30m',
#  '10h 25m',
#  '5h 15m',
#  '2h 30m',
#  '6h 15m',
#  '11h 55m',
#  '11h 5m',
#  '8h 30m',
#  '22h 5m',
#  '2h 45m',
#  '12h 0m',
#  '2h 50m',
#  '2h 50m',
#  '2h 15m',
#  '16h 5m',
#  '19h 55m',
#  '3h 15m',
#  '25h 20m',
#  '2h 50m',
#  '3h 0m',
#  '2h 50m',
#  '16h 15m',
#  '15h 5m',
#  '2h 15m',
#  '6h 30m',
#  '25h 5m',
#  '12h 25m',
#  '27h 20m',
#  '10h 15m',
#  '10h 30m',
#  '2h 15m',
#  '10h 25m',
#  '2h 50m',
#  '1h 30m',
#  '13h 20m',
#  '2h 15m',
#  '1h 25m',
#  '26h 30m',
#  '7h 20m',
#  '13h 30m',
#  '5h 0m',
# ...

# %%
data['Duration']=duration

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2024-10-10 22:20:00 2024-03-22 01:10:00   2h 50m    non-stop
# 1 2024-10-10 05:50:00 2024-10-10 13:15:00   7h 25m     2 stops
# 2 2024-10-10 09:25:00 2024-06-10 04:25:00   19h 0m     2 stops
# 3 2024-10-10 18:05:00 2024-10-10 23:30:00   5h 25m      1 stop
# 4 2024-10-10 16:50:00 2024-10-10 21:35:00   4h 45m      1 stop
#
#   Additional_Info  ...  Journet_month  Arrival_hour  Arrival_minute  \
# ...

# %%
data.shape
# Out:
# (10682, 21)

# %%
a = '12h 20m'

# %%
a.split(' ')
# Out:
# ['12h', '20m']

# %%
a.split(' ')[0]
# Out:
# '12h'

# %%
a.split(' ')[1]
# Out:
# '20m'

# %%
a.split(' ')[0][:-1]
# Out:
# '12'

# %%
int(a.split(' ')[0][:-1])
# Out:
# 12

# %%
h = int(a.split(' ')[0][:-1])

# %%
m = int(a.split(' ')[1][:-1])

# %%
h
# Out:
# 12

# %%
m
# Out:
# 20

# %%
def hour(i):
    return i.split(' ')[0][0:-1]
def minute(i):
    return i.split(' ')[1][0:-1]

# %% [markdown]
# # 6. adding new columns

# %%
data['Duration_hr']=data['Duration'].apply(hour)

# %%
data['Duration_min']=data['Duration'].apply(minute)

# %%
data.head(5)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2024-10-10 22:20:00 2024-03-22 01:10:00   2h 50m    non-stop
# 1 2024-10-10 05:50:00 2024-10-10 13:15:00   7h 25m     2 stops
# 2 2024-10-10 09:25:00 2024-06-10 04:25:00   19h 0m     2 stops
# 3 2024-10-10 18:05:00 2024-10-10 23:30:00   5h 25m      1 stop
# 4 2024-10-10 16:50:00 2024-10-10 21:35:00   4h 45m      1 stop
#
#   Additional_Info  ...  Arrival_minute  Arrival_Timehour  Arrival_Timeminute  \
# ...

# %%
data.dtypes
# Out:
# Airline                       object
# Date_of_Journey       datetime64[ns]
# Source                        object
# Destination                   object
# Route                         object
# Dep_Time              datetime64[ns]
# Arrival_Time          datetime64[ns]
# Duration                      object
# Total_Stops                   object
# Additional_Info               object
# Journet_date                   int32
# Journet_month                  int32
# Arrival_hour                   int32
# Arrival_minute                 int32
# Arrival_Timehour               int32
# Arrival_Timeminute             int32
# Dep_Timehour                   int32
# Dep_Timeminute                 int32
# Dep_date                       int32
# Dep_month                      int32
# Dep_year                       int32
# Duration_hr                   object
# Duration_min                  object
# dtype: object

# %%
data['Duration_hr']=data['Duration_hr'].astype(int)
data['Duration_min']=data['Duration_min'].astype(int)

# %%
data.dtypes
# Out:
# Airline                       object
# Date_of_Journey       datetime64[ns]
# Source                        object
# Destination                   object
# Route                         object
# Dep_Time              datetime64[ns]
# Arrival_Time          datetime64[ns]
# Duration                      object
# Total_Stops                   object
# Additional_Info               object
# Journet_date                   int32
# Journet_month                  int32
# Arrival_hour                   int32
# Arrival_minute                 int32
# Arrival_Timehour               int32
# Arrival_Timeminute             int32
# Dep_Timehour                   int32
# Dep_Timeminute                 int32
# Dep_date                       int32
# Dep_month                      int32
# Dep_year                       int32
# Duration_hr                    int32
# Duration_min                   int32
# dtype: object

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Journet_date', 'Journet_month', 'Arrival_hour',
#        'Arrival_minute', 'Arrival_Timehour', 'Arrival_Timeminute',
#        'Dep_Timehour', 'Dep_Timeminute', 'Dep_date', 'Dep_month', 'Dep_year',
#        'Duration_hr', 'Duration_min'],
#       dtype='object')

# %%
titles = list(data.columns)

# %%
titles
# Out:
# ['Airline',
#  'Date_of_Journey',
#  'Source',
#  'Destination',
#  'Route',
#  'Dep_Time',
#  'Arrival_Time',
#  'Duration',
#  'Total_Stops',
#  'Additional_Info',
#  'Journet_date',
#  'Journet_month',
#  'Arrival_hour',
#  'Arrival_minute',
#  'Arrival_Timehour',
#  'Arrival_Timeminute',
#  'Dep_Timehour',
#  'Dep_Timeminute',
#  'Dep_date',
#  'Dep_month',
#  'Dep_year',
#  'Duration_hr',
#  'Duration_min']

# %%
data.rename(columns = {'Journet_month':'Journey_month','Journet_date':'Journey_date'}, inplace=True)

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Journey_date', 'Journey_month', 'Arrival_hour',
#        'Arrival_minute', 'Arrival_Timehour', 'Arrival_Timeminute',
#        'Dep_Timehour', 'Dep_Timeminute', 'Dep_date', 'Dep_month', 'Dep_year',
#        'Duration_hr', 'Duration_min'],
#       dtype='object')

# %%
data.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2024-10-10 22:20:00 2024-03-22 01:10:00   2h 50m    non-stop
# 1 2024-10-10 05:50:00 2024-10-10 13:15:00   7h 25m     2 stops
# 2 2024-10-10 09:25:00 2024-06-10 04:25:00   19h 0m     2 stops
#
#   Additional_Info  ...  Arrival_minute  Arrival_Timehour  Arrival_Timeminute  \
# 0         No info  ...              10                 1                  10
# 1         No info  ...              15                13                  15
# 2         No info  ...              25                 4                  25
#
#    Dep_Timehour  Dep_Timeminute  Dep_date  Dep_month  Dep_year  Duration_hr  \
# ...

# %%
for i in ['Date_of_Journey','Additional_Info']:
    drop_column(data,i)

# %%
data.head(3)
# Out:
#        Airline    Source Destination                  Route  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK
#
#              Dep_Time        Arrival_Time Duration Total_Stops  Journey_date  \
# 0 2024-10-10 22:20:00 2024-03-22 01:10:00   2h 50m    non-stop            24
# 1 2024-10-10 05:50:00 2024-10-10 13:15:00   7h 25m     2 stops             1
# 2 2024-10-10 09:25:00 2024-06-10 04:25:00   19h 0m     2 stops             9
#
#    Journey_month  ...  Arrival_minute  Arrival_Timehour  Arrival_Timeminute  \
# 0              3  ...              10                 1                  10
# 1              5  ...              15                13                  15
# 2              6  ...              25                 4                  25
#
#    Dep_Timehour  Dep_Timeminute  Dep_date  Dep_month  Dep_year  Duration_hr  \
# ...

# %%
titles = list(data.columns)
titles
# Out:
# ['Airline',
#  'Source',
#  'Destination',
#  'Route',
#  'Dep_Time',
#  'Arrival_Time',
#  'Duration',
#  'Total_Stops',
#  'Journey_date',
#  'Journey_month',
#  'Arrival_hour',
#  'Arrival_minute',
#  'Arrival_Timehour',
#  'Arrival_Timeminute',
#  'Dep_Timehour',
#  'Dep_Timeminute',
#  'Dep_date',
#  'Dep_month',
#  'Dep_year',
#  'Duration_hr',
#  'Duration_min']

# %% [markdown]
# # 7. swaping columns

# %%
titles=['Airline',
 'Source',
 'Destination',
 'Journey_date',
 'Journey_month',
 'Route',
 'Total_Stops',
 'Arrival_hour',
 'Arrival_minute',
 'Arrival_Timehour',
 'Arrival_Timeminute',
 'Dep_Timehour',
 'Dep_Timeminute',
 'Dep_date',
 'Dep_month',
 'Dep_year',
 'Duration_hr',
 'Duration_min']

# %%
data = data[titles]

# %%
data.head(3)
# Out:
#        Airline    Source Destination  Journey_date  Journey_month  \
# 0       IndiGo  Banglore   New Delhi            24              3
# 1    Air India   Kolkata    Banglore             1              5
# 2  Jet Airways     Delhi      Cochin             9              6
#
#                    Route Total_Stops  Arrival_hour  Arrival_minute  \
# 0              BLR → DEL    non-stop             1              10
# 1  CCU → IXR → BBI → BLR     2 stops            13              15
# 2  DEL → LKO → BOM → COK     2 stops             4              25
#
#    Arrival_Timehour  Arrival_Timeminute  Dep_Timehour  Dep_Timeminute  \
# 0                 1                  10            22              20
# 1                13                  15             5              50
# 2                 4                  25             9              25
#
#    Dep_date  Dep_month  Dep_year  Duration_hr  Duration_min
# 0        10         10      2024            2            50
# ...

# %%
data.shape
# Out:
# (10682, 18)

# %% [markdown]
# # 8. giving some exact word to recognize the Total stop column

# %%
data['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %%
dict_a={'non-stop':0, '2 stops':2, '1 stop':1, '3 stops':3, '4 stops':4}

# %%
data['Total_Stops']=data['Total_Stops'].map(dict_a)
# Out:
# C:\Users\hari6\AppData\Local\Temp\ipykernel_21016\3120273206.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Total_Stops']=data['Total_Stops'].map(dict_a)

# %%
data['Total_Stops'].count
# Out:
# <bound method Series.count of 0        0
# 1        2
# 2        2
# 3        1
# 4        1
#         ..
# 10678    0
# 10679    0
# 10680    0
# 10681    0
# 10682    2
# Name: Total_Stops, Length: 10682, dtype: int64>

# %%
data.head(3)
# Out:
#        Airline    Source Destination  Journey_date  Journey_month  \
# 0       IndiGo  Banglore   New Delhi            24              3
# 1    Air India   Kolkata    Banglore             1              5
# 2  Jet Airways     Delhi      Cochin             9              6
#
#                    Route  Total_Stops  Arrival_hour  Arrival_minute  \
# 0              BLR → DEL            0             1              10
# 1  CCU → IXR → BBI → BLR            2            13              15
# 2  DEL → LKO → BOM → COK            2             4              25
#
#    Arrival_Timehour  Arrival_Timeminute  Dep_Timehour  Dep_Timeminute  \
# 0                 1                  10            22              20
# 1                13                  15             5              50
# 2                 4                  25             9              25
#
#    Dep_date  Dep_month  Dep_year  Duration_hr  Duration_min
# 0        10         10      2024            2            50
# ...

# %%
data.dtypes
# Out:
# Airline               object
# Source                object
# Destination           object
# Journey_date           int32
# Journey_month          int32
# Route                 object
# Total_Stops            int64
# Arrival_hour           int32
# Arrival_minute         int32
# Arrival_Timehour       int32
# Arrival_Timeminute     int32
# Dep_Timehour           int32
# Dep_Timeminute         int32
# Dep_date               int32
# Dep_month              int32
# Dep_year               int32
# Duration_hr            int32
# Duration_min           int32
# dtype: object

# %%
data['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
data['Airline'].count
# Out:
# <bound method Series.count of 0             IndiGo
# 1          Air India
# 2        Jet Airways
# 3             IndiGo
# 4             IndiGo
#             ...
# 10678       Air Asia
# 10679      Air India
# 10680    Jet Airways
# 10681        Vistara
# 10682      Air India
# Name: Airline, Length: 10682, dtype: object>

# %%
len(data['Airline'].unique())
# Out:
# 12

# %% [markdown]
# # 9. categorical data & numerical data vah inga namba pirikarum athuvathu dtypes la int nu irukura coulmns names la not equal to 'OBJECT' nu pota athu int data types la irukura columns name la list pani kuduthudum...`

# %% [markdown]
# # 10. athu meri namba catrgorical data nu entha columns la podrom nah 'OBJECT' nu irukura columns names la namaluku athu numerical ila nu katanum nu rathu ku kaga podurom...

# %%
category_data=[columns for columns in data.columns if data[columns].dtype=='O']

# %%
category_data
# Out:
# ['Airline', 'Source', 'Destination', 'Route']

# %%
continous_data=[columns for columns in data.columns if data[columns].dtype!='O']

# %%
continous_data
# Out:
# ['Journey_date',
#  'Journey_month',
#  'Total_Stops',
#  'Arrival_hour',
#  'Arrival_minute',
#  'Arrival_Timehour',
#  'Arrival_Timeminute',
#  'Dep_Timehour',
#  'Dep_Timeminute',
#  'Dep_date',
#  'Dep_month',
#  'Dep_year',
#  'Duration_hr',
#  'Duration_min']

# %% [markdown]
# # 11. here viewing the only obejct columns ie: a words columns

# %%
category_data=data[category_data]

# %%
category_data.head(3)
# Out:
#        Airline    Source Destination                  Route
# 0       IndiGo  Banglore   New Delhi              BLR → DEL
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK

# %% [markdown]
# # 12. here viewing the numbers columns

# %%
continous_data=data[continous_data]

# %%
continous_data.head(3)
# Out:
#    Journey_date  Journey_month  Total_Stops  Arrival_hour  Arrival_minute  \
# 0            24              3            0             1              10
# 1             1              5            2            13              15
# 2             9              6            2             4              25
#
#    Arrival_Timehour  Arrival_Timeminute  Dep_Timehour  Dep_Timeminute  \
# 0                 1                  10            22              20
# 1                13                  15             5              50
# 2                 4                  25             9              25
#
#    Dep_date  Dep_month  Dep_year  Duration_hr  Duration_min
# 0        10         10      2024            2            50
# 1        10         10      2024            7            25
# 2        10         10      2024           19             0

# %%
category_data['Airline'].value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1751
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %% [markdown]
# # 13. using matplotlib as pyplot as plt we are choosing box plot to view the overall total stops in Airline station

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x='Airline',y='Total_Stops',data=data.sort_values('Total_Stops',ascending=False))
# Out:
# <Axes: xlabel='Airline', ylabel='Total_Stops'>

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x='Airline',y='Journey_date',data=data.sort_values('Journey_date',ascending=False))
# Out:
# <Axes: xlabel='Airline', ylabel='Journey_date'>

# %%
data['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %% [markdown]
# # 13.1. get dummies

# %%
Airline=pd.get_dummies(category_data["Airline"])

# %%
category_data['Airline'].map({Trueue:1,False:0})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 category_data['Airline'].map({Trueue:1,False:0})
#
# NameError: name 'Trueue' is not defined

# %%
Airline.dtypes

# %%
category_data['Airline'].replace({True:1,False:0})

# %%
Airline.dtypes

# %%
category_data['Airline'].astype(int)

# %%
category_data['Airline'] = category_data['Airline'].astype(int)

# %%
Airline.dtypes

# %%
category_data.dtypes

# %%
Airline=pd.get_dummies(category_data["Airline"],drop_first=True,dtype=int)

# %%
Airline.head()

# %% [markdown]
# # 13.2. viewing the specific columns

# %%
data[['Airline']]

# %%
Airline.head()

# %%
category_data.columns

# %%
data['Source'].unique()

# %%
Source=pd.get_dummies(category_data['Source'],drop_first=True,dtype=int)

# %%
Source.head()

# %% [markdown]
# # 14. get dummies athuku ithuna vatti create panirukom nah category data la oru truth table create pana dhn.! categroical data la iruka ovru ovru columns dummies create ipdi last ah inga panirukom.. ---         INTHA METHOD KU PERU "ONE HOT ENCODING".

# %%
Destination=pd.get_dummies(category_data['Destination'],drop_first=True,dtype=int)

# %%
Destination.head(3)

# %%
category_data.head()

# %% [markdown]
# # 15. ipo inga intha Route column la iruka ovu city um thaniya thaniya pirichi aduthu route1,route2 nu poda porom

# %%
category_data['route_1']=category_data['Route'].str.split('→').str[0]

# %%
category_data.head()

# %%
category_data['Route'].unique()

# %%
category_data['route_2']=category_data['Route'].str.split('→').str[1]
category_data['route_3']=category_data['Route'].str.split('→').str[2]
category_data['route_4']=category_data['Route'].str.split('→').str[3]
category_data['route_5']=category_data['Route'].str.split('→').str[4]
category_data['route_6']=category_data['Route'].str.split('→').str[5]

# %%
category_data

# %%
data.dtypes

# %%
category_data.isna().sum()

# %%
category_data.shape

# %%
data.drop(['Route'],axis=1,inplace=True)

# %%
category_data.head(3)

# %%
for i in ['Route']:
    drop_column(category_data,i)

# %%
category_data.head(3)

# %%
category_data.columns

# %%
for i in ['route_3','route_4','route_5','route_6']:
    category_data[i].fillna('None',inplace=True)

# %%
category_data.head(3)

# %%
drop_column(category_data,'route_6')

# %%
category_data.head(3)

# %%
from sklearn .preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
for i in ['route_1','route_2','route_3','route_4','route_5']:
    category_data[i]=encoder.fit_transform(category_data[i])

# %%
category_data.head(5)

# %%
category_data['route_3'].unique()

# %%
new_data=pd.concat([category_data,Source,Airline,Destination,continous_data],axis=1)

# %%
new_data.head()

# %% [markdown]
# # 16. no.of columns increase pani paka dhn intha "DISPLAY MAX COMMAND USE PANROM"

# %%
pd.options.display.max_columns=40

# %%
for i in ['Airline','Source','Destination']:
    drop_column(new_data,i)

# %%
new_data.head()

# %%
new_data.dtypes

# %%
def plotting(df,column):
    fig,(ax1,ax2)=plt.subplots(2,1)
    sns.histplot(df[column],ax=ax1)
    sns.boxplot(df[column],ax=ax2)

# %%
plotting(new_data,'Total_Stops')
